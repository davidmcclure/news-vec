# %%
import pandas as pd

# %%
pd.options.display.max_rows = 100

# %%
lc = pd.read_json('../data/domain-link-counts.json/part-00000-92c7e08d-cf21-44b8-a362-8dbfc7dae410-c000.json', lines=True)

# %%
lc
# Out:
#        count                  domain
# 0   13798511             nytimes.com
# 1   12079379                 cnn.com
# 2   10208267      washingtonpost.com
# 3    8780829             thehill.com
# 4    8011778         theguardian.com
# 5    6838388             foxnews.com
# 6    6372195               bbc.co.uk
# 7    4581144             reuters.com
# 8    4380006           breitbart.com
# 9    4061263      huffingtonpost.com
# 10   3463485            politico.com
# 11   3310206       independent.co.uk
# 12   3086562             nbcnews.com
# 13   2985315           bloomberg.com
# 14   2928054              forbes.com
# 15   2897976               yahoo.com
# 16   2777987            buzzfeed.com
# 17   2670980                 wsj.com
# 18   2530164    thegatewaypundit.com
# 19   2456446     businessinsider.com
# 20   2243974            usatoday.com
# 21   2242512             cbsnews.com
# 22   2199757         dailycaller.com
# 23   2163952              apnews.com
# ...

# %%
ac = pd.read_json('../data/domain-article-counts.json/part-00000-4393bf5d-23c1-4e4a-a635-6085624a737f-c000.json', lines=True)

# %%
ac
# Out:
#      count                  domain
# 0   758047               yahoo.com
# 1   457027             reuters.com
# 2   416038               bbc.co.uk
# 3   293685             nytimes.com
# 4   290894         theguardian.com
# 5   263020      washingtonpost.com
# 6   252496                 msn.com
# 7   235377             foxnews.com
# 8   231410            usatoday.com
# 9   224984         telegraph.co.uk
# 10  212964                  cbc.ca
# 11  202803              forbes.com
# 12  199371                 cnn.com
# 13  191849     businessinsider.com
# 14  183896           bloomberg.com
# 15  173143      huffingtonpost.com
# 16  153122       independent.co.uk
# 17  133279              apnews.com
# 18  126504            buzzfeed.com
# 19  124386                cnbc.com
# 20  121375          thetimes.co.uk
# 21  115275           breitbart.com
# 22  111518                vice.com
# 23  107360                  ft.com
# 24  106947     washingtontimes.com
# 25  105914                 wsj.com
# ...

# %%
with open('../data/domains-50k.txt', 'w') as fh:
    for d in list(ac[ac['count'] > 50000].domain):
        pri
# Out:
# 0                  yahoo.com
# 1                reuters.com
# 2                  bbc.co.uk
# 3                nytimes.com
# 4            theguardian.com
# 5         washingtonpost.com
# 6                    msn.com
# 7                foxnews.com
# 8               usatoday.com
# 9            telegraph.co.uk
# 10                    cbc.ca
# 11                forbes.com
# 12                   cnn.com
# 13       businessinsider.com
# 14             bloomberg.com
# 15        huffingtonpost.com
# 16         independent.co.uk
# 17                apnews.com
# 18              buzzfeed.com
# 19                  cnbc.com
# 20            thetimes.co.uk
# 21             breitbart.com
# 22                  vice.com
# 23                    ft.com
# 24       washingtontimes.com
# 25                   wsj.com
# 26                nypost.com
# 27               thehill.com
# 28           nydailynews.com
# 29               cbsnews.com
# 30           sputniknews.com
# 31              dailykos.com
# ...

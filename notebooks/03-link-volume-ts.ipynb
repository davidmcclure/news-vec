# %%
import pandas as pd

from datetime import date

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %matplotlib inline

# %%
days = pd.read_json('../data/link-day-counts.json/part-00000-5ae47e52-be50-4899-ab6f-4bfcab96b8b2-c000.json', lines=True)

# %%
days['date'] = days.apply(lambda r: date(r.year, r.month, r.day), axis=1)

# %%
x = days.date.unique()

# %%
def plot_vol(df):
    
    counts = df.groupby('date').sum()['count']
    y = [counts.get(d, 0) for d in x]
    
    plt.figure(figsize=(20,3))
    plt.bar(x, y, linewidth=0, width=1)
    plt.show()

# %%
plot_vol(days)

# %%
for domain in days.domain.unique():
    print(domain)
    plot_vol(days[days.domain==domain])
# Out:
# nytimes.com
# aljazeera.com
# politico.com
# theatlantic.com
# usatoday.com
# cbsnews.com
# politicususa.com
# thinkprogress.org
# truepundit.com
# forbes.com
# newyorker.com
# nypost.com
# time.com
# vox.com
# foxnews.com
# bloomberg.com
# washingtontimes.com
# sputniknews.com
# washingtonexaminer.com
# cnbc.com
# slate.com
# judicialwatch.org
# pbs.org
# rt.com
# telegraph.co.uk
# breitbart.com
# palmerreport.com
# yahoo.com
# theconversation.com
# wsj.com
# propublica.org
# dailykos.com
# thefederalist.com
# nbcnews.com
# ft.com
# newsweek.com
# townhall.com
# realclearpolitics.com
# nydailynews.com
# independent.co.uk
# dailywire.com
# economist.com
# nationalreview.com
# rawstory.com
# hbr.org
# axios.com
# washingtonpost.com
# qz.com
# theblaze.com
# thedailybeast.com
# theroot.com
# thenation.com
# foxbusiness.com
# cnn.com
# crooksandliars.com
# buzzfeed.com
# salon.com
# npr.org
# apnews.com
# fortune.com
# msnbc.com
# bbc.co.uk
# talkingpointsmemo.com
# reuters.com
# msn.com
# newrepublic.com
# motherjones.com
# jezebel.com
# dailycaller.com
# fivethirtyeight.com
# huffingtonpost.com
# businessinsider.com
# thetimes.co.uk
# infowars.com
# hannity.com
# theguardian.com
# cbc.ca
# inc.com
# theintercept.com
# foreignpolicy.com
# thehill.com
# conservativereview.com
# vice.com
# thegatewaypundit.com
# nymag.com
# theonion.com
# variety.com

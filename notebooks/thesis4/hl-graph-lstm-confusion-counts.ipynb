# %%
import pandas as pd
import numpy as np

from itertools import combinations
from scipy import stats

from news_vec.encoder import read_preds

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %%
df, _ = read_preds('../../data/ava-lstm-attn/')
# Out:
# 100%|██████████| 283/283 [00:12<00:00, 21.81it/s]

# %%
DOMAINS = sorted(df.domain.unique().tolist())

# %%
df['p_true'] = df.apply(lambda r: r[f'p_{r.domain}'], 1)
df['domain_pred'] = df.apply(lambda r: DOMAINS[np.argmax([r[f'p_{d}'] for d in DOMAINS])], 1)

# %%
df_test = df[df.split=='test']

# %%
rows = []

# %%
for d1 in DOMAINS:
    
    d2_count = df_test[df_test.domain==d1].groupby('domain_pred').size().to_dict()
    
    for d2, count in d2_count.items():
        if d2 != d1:
            rows.append((d1, d2, count))

# %%
conf_df = pd.DataFrame(rows, columns=('d1', 'd2', 'count'))

# %%
conf_df.sort_values('count', ascending=False)
# Out:
#                      d1                  d2  count
# 197             wsj.com       bloomberg.com    362
# 72      dailycaller.com       breitbart.com    321
# 98          foxnews.com          apnews.com    275
# 27        bloomberg.com             wsj.com    267
# 177         thehill.com           msnbc.com    267
# 81      dailycaller.com         thehill.com    253
# 137           msnbc.com         thehill.com    232
# 64              cnn.com           msnbc.com    232
# 150             npr.org         nytimes.com    215
# 67              cnn.com         thehill.com    210
# 39        breitbart.com         thehill.com    209
# 207             wsj.com         nytimes.com    196
# 167         nytimes.com             wsj.com    192
# 100         foxnews.com       breitbart.com    192
# 56              cnn.com          apnews.com    189
# 115  huffingtonpost.com        buzzfeed.com    180
# 154         nytimes.com          apnews.com    179
# 188  washingtonpost.com        dailykos.com    174
# 164         nytimes.com             npr.org    169
# 109         foxnews.com         thehill.com    165
# 140             npr.org          apnews.com    164
# 57              cnn.com       bloomberg.com    156
# 92         dailykos.com           msnbc.com    155
# 66              cnn.com         nytimes.com    153
# 49         buzzfeed.com  huffingtonpost.com    145
# 11           apnews.com         thehill.com    140
# 6            apnews.com         foxnews.com    139
# 191  washingtonpost.com           msnbc.com    138
# 69              cnn.com             wsj.com    138
# 75      dailycaller.com        dailykos.com    136
# ..                  ...                 ...    ...
# 23        bloomberg.com             npr.org     23
# 127           msnbc.com       bloomberg.com     23
# 7            apnews.com  huffingtonpost.com     23
# 199             wsj.com        buzzfeed.com     23
# 20        bloomberg.com         foxnews.com     22
# 97         dailykos.com             wsj.com     22
# 46         buzzfeed.com     dailycaller.com     21
# 43         buzzfeed.com       bloomberg.com     21
# 179         thehill.com         nytimes.com     21
# 90         dailykos.com         foxnews.com     21
# 44         buzzfeed.com       breitbart.com     21
# 131           msnbc.com     dailycaller.com     20
# 55         buzzfeed.com             wsj.com     19
# 85         dailykos.com       bloomberg.com     19
# 19        bloomberg.com        dailykos.com     18
# 53         buzzfeed.com         thehill.com     16
# 12           apnews.com  washingtonpost.com     16
# 16        bloomberg.com        buzzfeed.com     16
# 18        bloomberg.com     dailycaller.com     14
# 202             wsj.com        dailykos.com     14
# 50         buzzfeed.com           msnbc.com     14
# 42         buzzfeed.com          apnews.com     14
# 30        breitbart.com        buzzfeed.com     12
# 201             wsj.com     dailycaller.com     11
# 48         buzzfeed.com         foxnews.com     10
# 45         buzzfeed.com             cnn.com      9
# 5            apnews.com        dailykos.com      8
# 2            apnews.com        buzzfeed.com      8
# 129           msnbc.com        buzzfeed.com      5
# 171         thehill.com        buzzfeed.com      3
#
# [210 rows x 3 columns]

# %%
conf_df.to_json('data/hl-graph-lstm-confusion-counts.json', orient='records', lines=True)

# %%
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# # Links

# %%
links = pd.read_json('data/domain-link-counts-5k.json/part-00000-84cd8982-56bb-4a96-9deb-1c97d26ec986-c000.json', lines=True)

# %%
links.head(10)
# Out:
#      count              domain
# 0  4281791         nytimes.com
# 1  3960164             cnn.com
# 2  2771013  washingtonpost.com
# 3  2502722     theguardian.com
# 4  2181704         thehill.com
# 5  2156544           bbc.co.uk
# 6  1779632         foxnews.com
# 7  1538265         reuters.com
# 8  1201324  huffingtonpost.com
# 9  1164391          forbes.com

# %%
plt.figure(figsize=(5,20))
sns.barplot(x='count', y='domain', data=links)

# %% [markdown]
# # Articles

# %%
articles = pd.read_json('data/domain-article-counts-5k.json/part-00000-1f14ac42-31e4-426a-bd30-5fde21494f97-c000.json', lines=True)

# %%
articles
# Out:
#      count                  domain
# 0   290094               yahoo.com
# 1   285846               bbc.co.uk
# 2   245369             reuters.com
# 3   206046         theguardian.com
# 4   185267                 cnn.com
# 5   182394                 msn.com
# 6   172633                  rt.com
# 7   170713             nytimes.com
# 8   156884      washingtonpost.com
# 9   143243              forbes.com
# 10  132002                  cbc.ca
# 11  125308         sputniknews.com
# 12  124240           bloomberg.com
# 13  124080      huffingtonpost.com
# 14  120753             foxnews.com
# 15  116843     businessinsider.com
# 16  110754            buzzfeed.com
# 17  109739            usatoday.com
# 18  103144         telegraph.co.uk
# 19  100117       independent.co.uk
# 20   94141                vice.com
# 21   89264                 wsj.com
# 22   86260                cnbc.com
# 23   76648             thehill.com
# 24   74137              apnews.com
# 25   69993                  ft.com
# ...

# %%
plt.figure(figsize=(5,20))
sns.barplot(x='count', y='domain', data=articles)

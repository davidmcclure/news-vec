# %%
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# # Links

# %%
links = pd.read_json('data/domain-link-counts-1k.json/part-00000-e8ec26f3-6cdd-4bec-8639-f49270871a8b-c000.json', lines=True)

# %%
links.head(10)
# Out:
#      count              domain
# 0  1613815         nytimes.com
# 1  1546122             cnn.com
# 2   966506     theguardian.com
# 3   952595  washingtonpost.com
# 4   889504           bbc.co.uk
# 5   819772         reuters.com
# 6   646077         thehill.com
# 7   635298         foxnews.com
# 8   558623          forbes.com
# 9   460065  huffingtonpost.com

# %%
plt.figure(figsize=(5,20))
sns.barplot(x='count', y='domain', data=links)

# %% [markdown]
# # Articles

# %%
articles = pd.read_json('data/domain-article-counts-1k.json/part-00000-b057e3a0-f092-4373-81e5-81426d2058a9-c000.json', lines=True)

# %%
articles
# Out:
#      count                  domain
# 0   188134               bbc.co.uk
# 1   150372         theguardian.com
# 2   143729               yahoo.com
# 3   141118             reuters.com
# 4   137544                 cnn.com
# 5   124688             nytimes.com
# 6   107783      washingtonpost.com
# 7   105459                  rt.com
# 8   100684              forbes.com
# 9    90007                 msn.com
# 10   84855      huffingtonpost.com
# 11   82159           bloomberg.com
# 12   81533                  cbc.ca
# 13   79242             foxnews.com
# 14   75623            buzzfeed.com
# 15   73251     businessinsider.com
# 16   66768       independent.co.uk
# 17   63033                 wsj.com
# 18   62814         telegraph.co.uk
# 19   62246            usatoday.com
# 20   59978                cnbc.com
# 21   59964         sputniknews.com
# 22   57462             thehill.com
# 23   55580                vice.com
# 24   44441           breitbart.com
# 25   44068                  ft.com
# ...

# %%
plt.figure(figsize=(5,20))
sns.barplot(x='count', y='domain', data=articles)

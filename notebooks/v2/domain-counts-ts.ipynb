# %%
import pandas as pd

from scipy import stats
from IPython.display import display, Markdown
from datetime import date, datetime as dt

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %%
pd.options.display.max_rows = 200

# %%
def load_ts_df(path):
    df = pd.read_json(path, lines=True)
    df['date'] = df[['year', 'month', 'day']].apply(lambda x: date(*x), axis=1)
    return df.sort_values('date')

# %%
def plot_ts(df, y='count', w=15, h=3):
    plt.figure(figsize=(w,h))
    plt.bar(list(df.date), df[y], linewidth=0, width=1)
    plt.show()

# %%
links = load_ts_df('data/domain-link-ts-counts.json/part-00000-fd8939b8-5608-4582-b944-ff69225f8912-c000.json')

# %%
actors = load_ts_df('data/domain-actor-ts-counts.json/part-00000-719a8558-d4f3-4b20-bfce-c65a70f3a9a0-c000.json')

# %%
articles = load_ts_df('data/domain-article-ts-counts.json/part-00000-52b127cd-f723-4a0a-b146-35159f7bccce-c000.json')

# %%
link_counts = pd.read_json('data/domain-link-counts.json/part-00000-d73512e3-ea00-4314-a7b9-10ddcd09b8b2-c000.json', lines=True)

# %%
for d in link_counts.domain:
    display(Markdown(f'# {d}'))
    print('Links')
    plot_ts(links[links.domain==d])
    print('Actors')
    plot_ts(actors[actors.domain==d])
    print('Articles')
    plot_ts(articles[articles.domain==d])
# Out:
# # nytimes.com
# Links
# Actors
# Articles
# # cnn.com
# Links
# Actors
# Articles
# # washingtonpost.com
# Links
# Actors
# Articles
# # thehill.com
# Links
# Actors
# Articles
# # theguardian.com
# Links
# Actors
# Articles
# # foxnews.com
# Links
# Actors
# Articles
# # bbc.co.uk
# Links
# Actors
# Articles
# # reuters.com
# Links
# Actors
# Articles
# # breitbart.com
# Links
# Actors
# Articles
# # huffingtonpost.com
# Links
# Actors
# Articles
# # politico.com
# Links
# Actors
# Articles
# # independent.co.uk
# Links
# Actors
# Articles
# # nbcnews.com
# Links
# Actors
# Articles
# # bloomberg.com
# Links
# Actors
# Articles
# # forbes.com
# Links
# Actors
# Articles
# # yahoo.com
# Links
# Actors
# Articles
# # buzzfeed.com
# Links
# Actors
# Articles
# # wsj.com
# Links
# Actors
# Articles
# # thegatewaypundit.com
# Links
# Actors
# Articles
# # businessinsider.com
# Links
# Actors
# Articles
# # cbsnews.com
# Links
# Actors
# Articles
# # usatoday.com
# Links
# Actors
# Articles
# # dailycaller.com
# Links
# Actors
# Articles
# # apnews.com
# Links
# Actors
# Articles
# # rawstory.com
# Links
# Actors
# Articles
# # npr.org
# Links
# Actors
# Articles
# # truepundit.com
# Links
# Actors
# Articles
# # vice.com
# Links
# Actors
# Articles
# # thedailybeast.com
# Links
# Actors
# Articles

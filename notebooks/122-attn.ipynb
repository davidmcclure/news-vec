# %%
from news_vec.encoder import read_preds

# %%
df, embeds = read_preds('../data/pred-attn/')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 36.24it/s]

# %%
df
# Out:
#                                                  title                        ...                                                                       attn
# 0    Exclusive - Report : Feds Force American Commu...                        ...                          [0.09087048, 0.09068244, 0.09051624, 0.0913435...
# 1    Farage Slams Jurnos Suggesting Fisherman be Sa...                        ...                          [0.08326305, 0.08382097, 0.083558396, 0.083393...
# 2       Adultery With a Difference on the London Stage                        ...                          [0.12460329, 0.12650074, 0.12550914, 0.1249825...
# 3    Khamenei : U.S. Created Islamic State to Distr...                        ...                          [0.09086225, 0.09094361, 0.09118332, 0.0908140...
# 4    * * SPONSORED CONTENT * * I Typed in My Name a...                        ...                          [0.07725911, 0.07739085, 0.07678811, 0.0769824...
# ...

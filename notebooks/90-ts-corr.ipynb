# %%
import pandas as pd

from news_vec.utils import read_json_gz_lines

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %matplotlib inline

# %%
df = pd.read_json('../data/window-actor-corrs2.json/part-00000-8549d2df-1b6a-4ecd-8c88-3b7025d29ec5-c000.json', lines=True)

# %%
pairs = set(map(tuple, df[['d1', 'd2']].values.tolist()))

# %%
for d1, d2 in pairs:
    pdf = df[(df.d1==d1)&(df.d2==d2)].sort_values('window')
    print(d1, d2)
    plt.ylim(-1, 1)
    plt.plot(pdf.window, pdf['corr'])
    plt.show()
# Out:
# buzzfeed.com breitbart.com
# foxnews.com rt.com
# washingtonpost.com thehill.com
# sputniknews.com foxnews.com
# dailykos.com dailycaller.com
# cnn.com dailycaller.com
# huffingtonpost.com apnews.com
# nytimes.com cnn.com
# sputniknews.com wsj.com
# npr.org breitbart.com
# washingtonpost.com breitbart.com
# dailykos.com rt.com
# foxnews.com npr.org
# nytimes.com npr.org
# wsj.com dailycaller.com
# buzzfeed.com thehill.com
# bloomberg.com wsj.com
# sputniknews.com washingtonpost.com
# thehill.com breitbart.com
# npr.org thehill.com
# nytimes.com apnews.com
# buzzfeed.com huffingtonpost.com
# dailykos.com apnews.com
# nytimes.com thehill.com
# sputniknews.com dailykos.com
# dailykos.com npr.org
# wsj.com dailykos.com
# nytimes.com rt.com
# nytimes.com sputniknews.com
# washingtonpost.com dailykos.com
# bloomberg.com buzzfeed.com
# washingtonpost.com huffingtonpost.com
# wsj.com buzzfeed.com
# dailykos.com foxnews.com
# sputniknews.com dailycaller.com
# wsj.com cnn.com
# ...

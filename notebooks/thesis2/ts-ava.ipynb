# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
from sklearn import preprocessing
from scipy import stats
from itertools import combinations

from news_vec.utils import read_json_gz_lines

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %matplotlib inline

# %%
df = pd.DataFrame(list(tqdm(read_json_gz_lines('../../data/clf-ts-acc-ava.json/'))))
# Out:
# 9100it [00:00, 310423.87it/s]

# %%
df.head(10)
# Out:
#         acc  window
# 0  0.285842       9
# 1  0.286437      34
# 2  0.279447      34
# 3  0.273200      87
# 4  0.270523      87
# 5  0.277811      87
# 6  0.274390      72
# 7  0.289560      24
# 8  0.278703      72
# 9  0.283313      24

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='window', y='acc', data=df)

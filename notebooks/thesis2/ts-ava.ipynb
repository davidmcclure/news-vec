# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
from sklearn import preprocessing
from scipy import stats
from itertools import combinations

from news_vec.utils import read_json_gz_lines

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

mpl.style.use('seaborn-muted')
sns.set(style="whitegrid")

# %matplotlib inline

# %%
df = pd.DataFrame(list(tqdm(read_json_gz_lines('../../data/clf-ava-ts-acc.json/'))))
# Out:
# 9100it [00:00, 266613.81it/s]

# %%
df.head(10)
# Out:
#         acc  window
# 0  0.319993       9
# 1  0.314687      34
# 2  0.313850      24
# 3  0.310033      72
# 4  0.302867      34
# 5  0.303425      72
# 6  0.308172      34
# 7  0.320737      13
# 8  0.316828       9
# 9  0.319806      28

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='window', y='acc', data=df)
